% %%
!dir
% Out:
% modelbc.m  model.ipynb	plot_t0.png   plot_t1.png   surff.png  surfn.png
% modelic.m  modelpde.m	plot_t10.png  plot_t20.png  surfm.png

% %%
cd 'Stage 5A'
% Out:
% Invalid expression. Check for missing multiplication operator, missing or
% unbalanced delimiters, or other syntax error. To construct matrices, use
% brackets instead of parentheses.

% %%
clearvars
close all
x = linspace(0,1,100);
t = 0:50;
m = 0;
sol = pdepe(m,@modelpde,@modelic,@modelbc,x,t);

% %%
n = sol(:,:,1);
f = sol(:,:,2);
m = sol(:,:,3);

% %%
surf(x,t,n)
title('n(x,t): Concentration of cancer cells')
xlabel('Distance x')
ylabel('Time t')
saveas(gcf, 'surfn.png');

% %%
surf(x,t,f)
title('f(x,t): Concentration of the ECM')
xlabel('Distance x')
ylabel('Time t')
saveas(gcf, 'surff.png');

% %%
surf(x,t,m)
title('m(x,t): Concentration of the MDEs')
xlabel('Distance x')
ylabel('Time t')
saveas(gcf, 'surfm.png');

% %%
plot(x,n(1,:))
hold on;
plot(x,f(1,:))
plot(x,m(1,:))
title('t=0')
xlabel('x');
legend('Cancer cells', 'ECM', 'MDE', 'Location', 'northeast');
hold off;
saveas(gcf, 'plot_t0.png');

% %%
plot(x,n(2,:))
hold on;
plot(x,f(2,:))
plot(x,m(2,:))
title('t=1')
legend('Cancer cells', 'ECM', 'MDE', 'Location', 'northeast');
saveas(gcf, 'plot_t1.png');
hold off;

% %%
plot(x,n(11,:))
hold on;
plot(x,f(11,:))
plot(x,m(11,:))
title('t=10')
ylim([0,1]);
legend('Cancer cells', 'ECM', 'MDE', 'Location', 'northwest');
saveas(gcf, 'plot_t10.png');
hold off;

% %%
plot(x,n(21,:))
hold on;
plot(x,f(21,:))
plot(x,m(21,:))
title('t=20')
legend('Cancer cells', 'ECM', 'MDE', 'Location', 'northwest');
saveas(gcf, 'plot_t20.png');
hold off;

% %%
plot(x,n(end,:))
hold on;
plot(x,f(end,:))
plot(x,m(end,:))
title('t=50')
legend('Cancer cells', 'ECM', 'MDE', 'Location', 'northwest');
saveas(gcf, 'plot_t50.png');
hold off;
